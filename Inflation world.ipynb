# %%
import numpy as np
import pandas as pd


from pandas import Series,DataFrame


xlsfile= pd.ExcelFile('API_FP.CPI.TOTL.ZG_DS2_en_excel_v2_4353242.xls')


dframe= xlsfile.parse('Data')

# %%
dframe.columns
# Out:
# Index(['Data Source', 'World Development Indicators', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
dframe.drop(0)
# Out:
#                      Data Source World Development Indicators  \
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# 5                    Afghanistan                          AFG
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                                 Unnamed: 2      Unnamed: 3   Unnamed: 4  \
# 1                                      NaN             NaN          NaN
# 2                           Indicator Name  Indicator Code  1960.000000
# ...

# %%
dframe.drop(1)
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2022-07-20 00:00:00
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# 5                    Afghanistan                          AFG
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                                 Unnamed: 2      Unnamed: 3   Unnamed: 4  \
# 0                                      NaN             NaN          NaN
# 2                           Indicator Name  Indicator Code  1960.000000
# ...

# %%
dframe= dframe.drop(0)

# %%
dframe
# Out:
#                      Data Source World Development Indicators  \
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# 5                    Afghanistan                          AFG
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                                 Unnamed: 2      Unnamed: 3   Unnamed: 4  \
# 1                                      NaN             NaN          NaN
# 2                           Indicator Name  Indicator Code  1960.000000
# ...

# %%
dframe=dframe.drop(1)

# %%
dframe
# Out:
#                      Data Source World Development Indicators  \
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# 5                    Afghanistan                          AFG
# 6     Africa Western and Central                          AFW
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                                 Unnamed: 2      Unnamed: 3   Unnamed: 4  \
# 2                           Indicator Name  Indicator Code  1960.000000
# 3    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG          NaN
# ...

# %%
dframe.index = pd.to_datetime(dframe.index)

# %%
dframe
# Out:
#                                                Data Source  \
# 1970-01-01 00:00:00.000000002                 Country Name
# 1970-01-01 00:00:00.000000003                        Aruba
# 1970-01-01 00:00:00.000000004  Africa Eastern and Southern
# 1970-01-01 00:00:00.000000005                  Afghanistan
# 1970-01-01 00:00:00.000000006   Africa Western and Central
# ...                                                    ...
# 1970-01-01 00:00:00.000000264                       Kosovo
# 1970-01-01 00:00:00.000000265                  Yemen, Rep.
# 1970-01-01 00:00:00.000000266                 South Africa
# 1970-01-01 00:00:00.000000267                       Zambia
# 1970-01-01 00:00:00.000000268                     Zimbabwe
#
#                               World Development Indicators  \
# 1970-01-01 00:00:00.000000002                 Country Code
# 1970-01-01 00:00:00.000000003                          ABW
# 1970-01-01 00:00:00.000000004                          AFE
# ...

# %%
dframe=dframe.drop('Data Source',axis=1)

# %%
dframe
# Out:
#                               World Development Indicators  \
# 1970-01-01 00:00:00.000000002                 Country Code
# 1970-01-01 00:00:00.000000003                          ABW
# 1970-01-01 00:00:00.000000004                          AFE
# 1970-01-01 00:00:00.000000005                          AFG
# 1970-01-01 00:00:00.000000006                          AFW
# ...                                                    ...
# 1970-01-01 00:00:00.000000264                          XKX
# 1970-01-01 00:00:00.000000265                          YEM
# 1970-01-01 00:00:00.000000266                          ZAF
# 1970-01-01 00:00:00.000000267                          ZMB
# 1970-01-01 00:00:00.000000268                          ZWE
#
#                                                           Unnamed: 2  \
# 1970-01-01 00:00:00.000000002                         Indicator Name
# 1970-01-01 00:00:00.000000003  Inflation, consumer prices (annual %)
# ...

# %%
dframe=dframe.drop('Unnamed: 2',axis=1)

# %%
dframe.head()
# Out:
#                               World Development Indicators      Unnamed: 3  \
# 1970-01-01 00:00:00.000000002                 Country Code  Indicator Code
# 1970-01-01 00:00:00.000000003                          ABW  FP.CPI.TOTL.ZG
# 1970-01-01 00:00:00.000000004                          AFE  FP.CPI.TOTL.ZG
# 1970-01-01 00:00:00.000000005                          AFG  FP.CPI.TOTL.ZG
# 1970-01-01 00:00:00.000000006                          AFW  FP.CPI.TOTL.ZG
#
#                                Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 1970-01-01 00:00:00.000000002      1960.0      1961.0      1962.0      1963.0
# 1970-01-01 00:00:00.000000003         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000004         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000005         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000006         NaN         NaN         NaN         NaN
#
# ...

# %%
dframe=dframe.drop('Unnamed: 3',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-167629d839cf> in <module>
# ----> 1 dframe=dframe.drop('Unnamed: 3',axis=1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
dframe
# Out:
#                               World Development Indicators   Unnamed: 4  \
# 1970-01-01 00:00:00.000000002                 Country Code  1960.000000
# 1970-01-01 00:00:00.000000003                          ABW          NaN
# 1970-01-01 00:00:00.000000004                          AFE          NaN
# 1970-01-01 00:00:00.000000005                          AFG          NaN
# 1970-01-01 00:00:00.000000006                          AFW          NaN
# ...                                                    ...          ...
# 1970-01-01 00:00:00.000000264                          XKX          NaN
# 1970-01-01 00:00:00.000000265                          YEM          NaN
# 1970-01-01 00:00:00.000000266                          ZAF     1.288859
# 1970-01-01 00:00:00.000000267                          ZMB          NaN
# 1970-01-01 00:00:00.000000268                          ZWE          NaN
#
#                                 Unnamed: 5   Unnamed: 6  Unnamed: 7  \
# ...

# %%
dframe=dframe.drop(Index,axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-fcc38f3a1d47> in <module>
# ----> 1 dframe=dframe.drop(Index,axis=1)
#
# NameError: name 'Index' is not defined

# %%
dframe = dframe.iloc[1: , :]

# %%
dframe
# Out:
#                               World Development Indicators  Unnamed: 4  \
# 1970-01-01 00:00:00.000000003                          ABW         NaN
# 1970-01-01 00:00:00.000000004                          AFE         NaN
# 1970-01-01 00:00:00.000000005                          AFG         NaN
# 1970-01-01 00:00:00.000000006                          AFW         NaN
# 1970-01-01 00:00:00.000000007                          AGO         NaN
# ...                                                    ...         ...
# 1970-01-01 00:00:00.000000264                          XKX         NaN
# 1970-01-01 00:00:00.000000265                          YEM         NaN
# 1970-01-01 00:00:00.000000266                          ZAF    1.288859
# 1970-01-01 00:00:00.000000267                          ZMB         NaN
# 1970-01-01 00:00:00.000000268                          ZWE         NaN
#
#                                Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# ...

# %%
DataFrame(reshape((266,63)),index=['A','B','D','E','F'],
                                     columns=['col1','col2','col3','col4','col5'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-cdf5296cbbee> in <module>
# ----> 1 DataFrame(reshape((266,63)),index=['A','B','D','E','F'],
#       2                                      columns=['col1','col2','col3','col4','col5'])
#
# NameError: name 'reshape' is not defined

# %%
dframe.columns
# Out:
# Index(['World Development Indicators', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42',
#        'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46',
#        'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50',
#        'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54',
#        'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58',
# ...

# %%
dframe.iloc[: , 1:]
# Out:
#                                Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 1970-01-01 00:00:00.000000003         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000004         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000005         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000006         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000007         NaN         NaN         NaN         NaN
# ...                                   ...         ...         ...         ...
# 1970-01-01 00:00:00.000000264         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000265         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000266    1.288859    2.102374    1.246285     1.33797
# 1970-01-01 00:00:00.000000267         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000268         NaN         NaN         NaN         NaN
#
# ...

# %%
dframe.head()
# Out:
#                               World Development Indicators  Unnamed: 4  \
# 1970-01-01 00:00:00.000000003                          ABW         NaN
# 1970-01-01 00:00:00.000000004                          AFE         NaN
# 1970-01-01 00:00:00.000000005                          AFG         NaN
# 1970-01-01 00:00:00.000000006                          AFW         NaN
# 1970-01-01 00:00:00.000000007                          AGO         NaN
#
#                                Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 1970-01-01 00:00:00.000000003         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000004         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000005         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000006         NaN         NaN         NaN         NaN
# 1970-01-01 00:00:00.000000007         NaN         NaN         NaN         NaN
#
# ...

# %%
dframe.reset_index(inplace=True)
dframe = dframe.rename(columns = {'index':'Year'})

# %%
dframe
# Out:
#      level_0                          Year World Development Indicators  \
# 0          0 1970-01-01 00:00:00.000000003                          ABW
# 1          1 1970-01-01 00:00:00.000000004                          AFE
# 2          2 1970-01-01 00:00:00.000000005                          AFG
# 3          3 1970-01-01 00:00:00.000000006                          AFW
# 4          4 1970-01-01 00:00:00.000000007                          AGO
# ..       ...                           ...                          ...
# 261      261 1970-01-01 00:00:00.000000264                          XKX
# 262      262 1970-01-01 00:00:00.000000265                          YEM
# 263      263 1970-01-01 00:00:00.000000266                          ZAF
# 264      264 1970-01-01 00:00:00.000000267                          ZMB
# 265      265 1970-01-01 00:00:00.000000268                          ZWE
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
dframe.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-625b4d08e6b0> in <module>
# ----> 1 dframe.dtype()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
print(dframe.dtypes)
# Out:
# level_0                                  int64
# Year                            datetime64[ns]
# World Development Indicators            object
# Unnamed: 4                             float64
# Unnamed: 5                             float64
#                                      ...
# Unnamed: 61                            float64
# Unnamed: 62                            float64
# Unnamed: 63                            float64
# Unnamed: 64                            float64
# Unnamed: 65                            float64
# Length: 65, dtype: object

# %%
import plotly.graph_objects as go
